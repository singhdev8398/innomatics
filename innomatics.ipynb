# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("movies.csv")

# %%
df.shape
# Out:
# (9742, 3)

# %%
rating=pd.read_csv("ratings.csv")

# %%
rating.shape
# Out:
# (100836, 4)

# %%
rating
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
len(rating['userId'].unique())
# Out:
# 610

# %%
df
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
movie=df.merge(rating,on="movieId")

# %%
movie
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
movie["rating"].max()
# Out:
# 5.0

# %%
dd=movie[movie["rating"]==5.0]

# %%
dd["title"].value_counts()
# Out:
# Shawshank Redemption, The (1994)             153
# Pulp Fiction (1994)                          123
# Forrest Gump (1994)                          116
# Matrix, The (1999)                           109
# Star Wars: Episode IV - A New Hope (1977)    104
#                                             ...
# Hello, Dolly! (1969)                           1
# Day of the Dead (1985)                         1
# Millennium Actress (Sennen joyû) (2001)        1
# Out of the Past (1947)                         1
# Won't You Be My Neighbor? (2018)               1
# Name: title, Length: 2954, dtype: int64

# %%
tag=pd.read_csv("tags.csv")

# %%
mov_out=movie.merge(tag,on="movieId")

# %%
mov_out
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
df3=mov_out[mov_out['title']== "Matrix, The (1999)"]

# %%
df3
# Out:
#         movieId               title                  genres  userId_x  rating  \
# 142140     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller         1     5.0
# 142141     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller         1     5.0
# 142142     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller         1     5.0
# 142143     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller         1     5.0
# 142144     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller         1     5.0
# ...         ...                 ...                     ...       ...     ...
# 143525     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       610     5.0
# 143526     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       610     5.0
# 143527     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       610     5.0
# 143528     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       610     5.0
# 143529     2571  Matrix, The (1999)  Action|Sci-Fi|Thriller       610     5.0
#
# ...

# %%
df3['tag'].uniqueque()
# Out:
# array(['martial arts', 'sci-fi', 'alternate universe', 'philosophy',
#        'post apocalyptic'], dtype=object)

# %%
userrating=mov_out[mov_out['title']=="Terminator 2: Judgment Day (1991)"]
userrating
# Out:
#        movieId                              title         genres  userId_x  \
# 93035      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi         5
# 93036      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi         5
# 93037      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi         5
# 93038      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi         5
# 93039      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi         5
# ...        ...                                ...            ...       ...
# 94822      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       610
# 94823      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       610
# 94824      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       610
# 94825      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       610
# 94826      589  Terminator 2: Judgment Day (1991)  Action|Sci-Fi       610
#
# ...

# %%
userrating["rating"].sum()
# Out:
# 7116.0

# %%
len(userrating["rating"])
# Out:
# 1792

# %%
userrating["rating"].sum()/len(userrating["rating"])
# Out:
# 3.970982142857143

# %%
Fight=mov_out[mov_out['title']=="Fight Club (1999)"]
Fight
# Out:
#         movieId              title                       genres  userId_x  \
# 148882     2959  Fight Club (1999)  Action|Crime|Drama|Thriller         1
# 148883     2959  Fight Club (1999)  Action|Crime|Drama|Thriller         1
# 148884     2959  Fight Club (1999)  Action|Crime|Drama|Thriller         1
# 148885     2959  Fight Club (1999)  Action|Crime|Drama|Thriller         1
# 148886     2959  Fight Club (1999)  Action|Crime|Drama|Thriller         1
# ...         ...                ...                          ...       ...
# 160649     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       610
# 160650     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       610
# 160651     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       610
# 160652     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       610
# 160653     2959  Fight Club (1999)  Action|Crime|Drama|Thriller       610
#
#         rating  timestamp_x  userId_y                tag  timestamp_y
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(Fight['rating'])
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_41240\3241579243.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Fight['rating'])
# <Axes: xlabel='rating', ylabel='Density'>

# %%
mov_out['rating'].sum()/mov_out.shape[0]
# Out:
# 3.9665348844189645

# %%
avg_movie_rating1=mov_out[mov_out['rating']==4.0]
avg_movie_rating1
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233198   187593               Deadpool 2 (2018)
# 233199   187595  Solo: A Star Wars Story (2018)
# 233200   187595  Solo: A Star Wars Story (2018)
# 233201   187595  Solo: A Star Wars Story (2018)
# 233202   187595  Solo: A Star Wars Story (2018)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
avg_movie_rating1['title'].value_counts()[0:6]
# Out:
# Pulp Fiction (1994)                                               13937
# Fight Club (1999)                                                  2646
# Star Wars: Episode IV - A New Hope (1977)                          1898
# Eternal Sunshine of the Spotless Mind (2004)                       1462
# 2001: A Space Odyssey (1968)                                       1435
# Léon: The Professional (a.k.a. The Professional) (Léon) (1994)     1295
# Name: title, dtype: int64

# %%
mov_out["genre"]=mov_out['genres'].str.split("|").str[-1]
mov_out
# Out:
#         movieId                           title  \
# 0             1                Toy Story (1995)
# 1             1                Toy Story (1995)
# 2             1                Toy Story (1995)
# 3             1                Toy Story (1995)
# 4             1                Toy Story (1995)
# ...         ...                             ...
# 233208   187595  Solo: A Star Wars Story (2018)
# 233209   193565       Gintama: The Movie (2010)
# 233210   193565       Gintama: The Movie (2010)
# 233211   193565       Gintama: The Movie (2010)
# 233212   193565       Gintama: The Movie (2010)
#
#                                              genres  userId_x  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 2       Adventure|Animation|Children|Comedy|Fantasy         1     4.0
# 3       Adventure|Animation|Children|Comedy|Fantasy         5     4.0
# ...

# %%
scifi=mov_out[mov_out['genre']=="Sci-Fi"]
scifi
# Out:
#         movieId                                              title  \
# 1902         29  City of Lost Children, The (Cité des enfants p...
# 1903         29  City of Lost Children, The (Cité des enfants p...
# 1904         29  City of Lost Children, The (Cité des enfants p...
# 1905         29  City of Lost Children, The (Cité des enfants p...
# 1906         29  City of Lost Children, The (Cité des enfants p...
# ...         ...                                                ...
# 233208   187595                     Solo: A Star Wars Story (2018)
# 233209   193565                          Gintama: The Movie (2010)
# 233210   193565                          Gintama: The Movie (2010)
# 233211   193565                          Gintama: The Movie (2010)
# 233212   193565                          Gintama: The Movie (2010)
#
#                                         genres  userId_x  rating  timestamp_x  \
# 1902    Adventure|Drama|Fantasy|Mystery|Sci-Fi        23     4.0   1107341574
# ...

# %%
scifi.groupby(by="title").mean()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_41240\204350089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   scifi.groupby(by="title").mean()
#                                                 movieId    userId_x    rating  \
# title
# 2001: A Space Odyssey (1968)                      924.0  292.486239  3.894495
# 28 Days Later (2002)                             6502.0  299.724138  3.974138
# A.I. Artificial Intelligence (2001)              4370.0  345.500000  3.339286
# Akira (1988)                                     1274.0  355.256410  3.743590
# Alien (1979)                                     1214.0  312.691781  3.969178
# ...                                                 ...         ...       ...
# Unbreakable (2000)                               3994.0  340.739726  3.479452
# ...

# %%
a=scifi[scifi['rating']==5.0]

# %%
a['title'].value_counts()
# Out:
# Star Wars: Episode IV - A New Hope (1977)                2704
# 2001: A Space Odyssey (1968)                             1394
# Eternal Sunshine of the Spotless Mind (2004)             1122
# Star Wars: Episode V - The Empire Strikes Back (1980)     800
# Terminator 2: Judgment Day (1991)                         512
#                                                          ...
# Jetée, La (1962)                                            1
# Ghostbusters II (1989)                                      1
# Bill & Ted's Bogus Journey (1991)                           1
# Short Circuit (1986)                                        1
# My Stepmother Is an Alien (1988)                            1
# Name: title, Length: 73, dtype: int64

# %%
mov_out.groupby(by="movieId").count()
# Out:
#          title  genres  userId_x  rating  timestamp_x  userId_y  tag  \
# movieId
# 1          645     645       645     645          645       645  645
# 2          440     440       440     440          440       440  440
# 3          104     104       104     104          104       104  104
# 5           98      98        98      98           98        98   98
# 7           54      54        54      54           54        54   54
# ...        ...     ...       ...     ...          ...       ...  ...
# 183611       3       3         3       3            3         3    3
# 184471      12      12        12      12           12        12   12
# 187593      36      36        36      36           36        36   36
# 187595      10      10        10      10           10        10   10
# 193565       4       4         4       4            4         4    4
#
#          timestamp_y  genre
# movieId
# 1                645    645
# 2                440    440
# 3                104    104
# ...

# %%
mov_out[mov_out['movieId']==3]
# Out:
#       movieId                    title          genres  userId_x  rating  \
# 1085        3  Grumpier Old Men (1995)  Comedy|Romance         1     4.0
# 1086        3  Grumpier Old Men (1995)  Comedy|Romance         1     4.0
# 1087        3  Grumpier Old Men (1995)  Comedy|Romance         6     5.0
# 1088        3  Grumpier Old Men (1995)  Comedy|Romance         6     5.0
# 1089        3  Grumpier Old Men (1995)  Comedy|Romance        19     3.0
# ...       ...                      ...             ...       ...     ...
# 1184        3  Grumpier Old Men (1995)  Comedy|Romance       594     4.0
# 1185        3  Grumpier Old Men (1995)  Comedy|Romance       599     1.5
# 1186        3  Grumpier Old Men (1995)  Comedy|Romance       599     1.5
# 1187        3  Grumpier Old Men (1995)  Comedy|Romance       608     2.0
# 1188        3  Grumpier Old Men (1995)  Comedy|Romance       608     2.0
#
#       timestamp_x  userId_y    tag  timestamp_y    genre
# ...

# %%
imdb=pd.read_csv("links.csv")
imdb
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9737   193581  5476944  432131.0
# 9738   193583  5914996  445030.0
# 9739   193585  6397426  479308.0
# 9740   193587  8391976  483455.0
# 9741   193609   101726   37891.0
#
# [9742 rows x 3 columns]

# %%
fdf=mov_out.merge(imdb, on="movieId")

# %%
fdf[fdf['rating']==5.0].groupby(by='movieId').count()
# Out:
#          title  genres  userId_x  rating  timestamp_x  userId_y  tag  \
# movieId
# 1          141     141       141     141          141       141  141
# 2           28      28        28      28           28        28   28
# 3           12      12        12      12           12        12   12
# 5            6       6         6       6            6         6    6
# 7            2       2         2       2            2         2    2
# ...        ...     ...       ...     ...          ...       ...  ...
# 174053      15      15        15      15           15        15   15
# 174055       6       6         6       6            6         6    6
# 176371      24      24        24      24           24        24   24
# 187593      12      12        12      12           12        12   12
# 187595       2       2         2       2            2         2    2
#
#          timestamp_y  genre  imdbId  tmdbId
# movieId
# 1                141    141     141     141
# ...

# %%
fdf[fdf["title"]=="Star Wars: Episode IV - A New Hope (1977)" ]
# Out:
#        movieId                                      title  \
# 12542      260  Star Wars: Episode IV - A New Hope (1977)
# 12543      260  Star Wars: Episode IV - A New Hope (1977)
# 12544      260  Star Wars: Episode IV - A New Hope (1977)
# 12545      260  Star Wars: Episode IV - A New Hope (1977)
# 12546      260  Star Wars: Episode IV - A New Hope (1977)
# ...        ...                                        ...
# 19063      260  Star Wars: Episode IV - A New Hope (1977)
# 19064      260  Star Wars: Episode IV - A New Hope (1977)
# 19065      260  Star Wars: Episode IV - A New Hope (1977)
# 19066      260  Star Wars: Episode IV - A New Hope (1977)
# 19067      260  Star Wars: Episode IV - A New Hope (1977)
#
#                         genres  userId_x  rating  timestamp_x  userId_y  \
# 12542  Action|Adventure|Sci-Fi         1     5.0    964981680        63
# 12543  Action|Adventure|Sci-Fi         1     5.0    964981680        63
# ...
